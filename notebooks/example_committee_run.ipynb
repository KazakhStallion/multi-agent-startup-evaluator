# %% [markdown]
# # Committee pipeline smoke test
#
# Run from repo root or set `PYTHONPATH` to the project root so `run_committee_pipeline` imports. Easiest: open this notebook from the capstone folder in Jupyter/VS Code.
#
# Requires API keys in the environment for full LLM behavior; without keys you still get JSON via local fallbacks (weaker text).

# %%
import json
import sys
from pathlib import Path

ROOT = Path.cwd()
if not (ROOT / "run_committee_pipeline.py").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from run_committee_pipeline import run_committee_pipeline

# Flip to True for the peer revision pass (6 extra API calls)
result = run_committee_pipeline(second_round=False)
print(result)

# %%
# Inspect last written PayFlow trace (path matches default fixture name)
p = ROOT / "data" / "committee_pipeline" / "payflow_committee_pipeline.json"
doc = json.loads(p.read_text(encoding="utf-8"))
print("keys:", sorted(doc.keys()))
print("moderator:", doc.get("moderator_output", {}).get("final_decision"))
print("second_round meta:", doc.get("pipeline_meta"))
